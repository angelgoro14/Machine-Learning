# %% [markdown]
# # MOS1

# %% [markdown]
# Instrucciones: Cargar los datos de las siguientes maneras
# - Desde github o  URL
# - Desde máquina local
#
# Recursos:
#
# - [Datasets de Kaggle](https://www.kaggle.com/datasets)

# %%
# DESDE URL (Github)

# Subir el archivo a un repositorio nuevo
# Dar click sobre el archivo subido
# Seleccionar "View RAW" y copiar el link completo desde la direccion, en la parte de arriba

import pandas as pd
movies = pd.read_csv("https://raw.githubusercontent.com/angelgoro14/kaggle_1/main/MoviesOnStreamingPlatforms_updated.csv")

# Muestra unicamente los primeros 7 datos
movies.head(7)

# Muestra todos los datos
#movies

# Si se tiene una sola columna, podemos separar los datos de la siguiente forma:
# movies = pd.read_csv('https://raw.githubusercontent.com', sep = ';')
# Out:
#    Unnamed: 0  ID  ...                 Language  Runtime
# 0           0   1  ...  English,Japanese,French    148.0
# 1           1   2  ...                  English    136.0
# 2           2   3  ...                  English    149.0
# 3           3   4  ...                  English    116.0
# 4           4   5  ...                  Italian    161.0
# 5           5   6  ...          English,Spanish    117.0
# 6           6   7  ...   English,German,Russian    150.0
#
# [7 rows x 17 columns]

# %%
# Desde Maquina Local (Cargado desde mi laptop a Colab)

# Colocar el archivo en la carpeta de archivos de Colab 
import pandas as pd
movies_1 = pd.read_csv("MoviesOnStreamingPlatforms_updated.csv")
movies_1
# Out:
#        Unnamed: 0     ID  ...                 Language  Runtime
# 0               0      1  ...  English,Japanese,French    148.0
# 1               1      2  ...                  English    136.0
# 2               2      3  ...                  English    149.0
# 3               3      4  ...                  English    116.0
# 4               4      5  ...                  Italian    161.0
# ...           ...    ...  ...                      ...      ...
# 16739       16739  16740  ...                  English    120.0
# 16740       16740  16741  ...                  English     90.0
# 16741       16741  16742  ...                  English      NaN
# 16742       16742  16743  ...                  English      NaN
# 16743       16743  16744  ...                  English     32.0
#
# [16744 rows x 17 columns]

# %% [markdown]
# ____________________________________________________________________________________________
