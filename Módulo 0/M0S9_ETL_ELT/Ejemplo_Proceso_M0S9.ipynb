# %% [markdown]
# # Procesos ETL/ELT con Python - ¿Qué herramientas existen?

# %% [markdown]
# **Recursos: Herramientas para procesos ETL/ELT:**
# - [Hevo](https://hevodata.com/)
# - [Petl](https://petl.readthedocs.io/en/stable/)
# - [Pandas](https://pandas.pydata.org/)
# - [Apache airflow](https://airflow.apache.org/)
# - [Pyspark](https://spark.apache.org/docs/latest/api/python/)
# - [Luigi](https://github.com/spotify/luigi)
# - ¿Puedes buscar otros? Te reto a hacer un benchmarking

# %%
import pandas as pd

df = pd.read_csv("merged_data_cleaned.csv")
df.head(5)
# Out:
#    Unnamed: 0  Species  ... altitude_high_meters altitude_mean_meters
# 0           0  Arabica  ...               2200.0               2075.0
# 1           1  Arabica  ...               2200.0               2075.0
# 2           2  Arabica  ...               1800.0               1700.0
# 3           3  Arabica  ...               2200.0               2000.0
# 4           4  Arabica  ...               2200.0               2075.0
#
# [5 rows x 44 columns]

# %% [markdown]
# Escanea visualmente cada columna (atributo), y escribe qué proceso de limpieza podrías hacer.
#
# **Quality Measures**
# - Aroma
# - Flavor
# - Aftertaste
# - Acidity
# - Body
# - Balance
# - Uniformity
# - Cup Cleanliness
# - Sweetness
# - Moisture
# - Defects
#
# **Bean Metadata**
# - Processing Method
# - Color
# - Species (arabica / robusta)
#
# **Farm Metadata**
# - Owner
# - Country of Origin
# - Farm Name
# - Lot Number: Revisar si todos son Nan
# - Mill
# - Company
# - Altitude: Son todos metros? Quitar la unidad de medida? es high-low?
# - Region
# - Bag.weght: Quitar unidad de medida.
