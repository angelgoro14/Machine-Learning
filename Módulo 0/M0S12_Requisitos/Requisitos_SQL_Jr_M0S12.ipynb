# %% [markdown]
# #Prueba técnica para el ROL de SQL Junior
#
# 1. Escriba un programa en Python para crear una base de datos SQLite y conéctese con la base de datos; imprima la versión de la base de datos SQLite.

# %% [markdown]
# 2. Escriba un programa en Python para crear una conexión de base de datos SQLite a una base de datos que resida en la memoria.

# %% [markdown]
# 3. Escriba un programa en Python para conectar una base de datos y crear una tabla SQLite dentro de la base de datos.

# %% [markdown]
# 4. Escriba un programa en Python para enumerar las tablas de un archivo de base de datos SQLite dado.

# %% [markdown]
# 5. Escriba un programa en Python para crear una tabla e inserte algunos registros en esa tabla. Finalmente selecciona todas las filas de la tabla y muestra los registros.

# %% [markdown]
# 6. Escriba un programa en Python para insertar una lista de registros en una tabla SQLite determinada.

# %% [markdown]
# 7. Escriba un programa Python para insertar valores en una tabla desde la entrada del usuario. (Use la función input)

# %% [markdown]
# 8. Escriba un programa en Python para contar el número de filas de una tabla SQLite determinada.

# %% [markdown]
# 9. Escriba un programa en Python para actualizar un valor de columna específico de una tabla dada y seleccione todas las filas antes y después de actualizar dicha tabla.

# %% [markdown]
# 10. Escriba un programa en Python para actualizar todos los valores de una columna específica de una tabla SQLite determinada.

# %% [markdown]
# 11. Escriba un programa en Python para eliminar una fila específica de una tabla SQLite determinada.

# %% [markdown]
# 12. Escriba un programa en Python para alterar una tabla SQLite determinada.

# %% [markdown]
# 13. Escriba un programa en Python para crear una copia de seguridad de una base de datos SQLite.

# %% [markdown]
# 14. Crea las siguientes tablas:
#  - a) Hospitales
#  - b) Doctores

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# La relación que existe entre las tablas es esta:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 15. Implemente dos funciones para leer los detalles de un médico determinado desde la Tabla Doctores y el Hospital desde la Tabla Hopitales. En otras palabras, lea los registros de las Tablas Hospitales y Doctores según el ID del hospital y el ID del médico.

# %%
def get_hospital_details(hospital_id):
    #Read data from Hospital table
    pass

def get_doctor_details(doctor_id):
    # Read data from Doctor table
    pass

get_hospital_details(2)
get_doctor_details(105)

# %% [markdown]
# **NOTA: El resultado debe verse como sigue**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 16. Obtenga la lista de médicos según la especialidad y el salario dados
#
# **Nota: Busque a todos los médicos cuyo salario sea superior a la cantidad de entrada y la especialidad sea la misma que la especialidad de entrada.**

# %%
def get_specialist_doctors_list(speciality, salary):
    #Fetch doctor's details as per Speciality and Salary
    pass
    
get_specialist_doctors_list("Garnacologist", 30000)

# %% [markdown]
# **NOTA: El resultado debe verse como sigue**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 17. Obtenega una lista de médicos de un hospital determinado
#
# Nota: Implemente la funcionalidad para buscar a todos los médicos según el ID de hospital proporcionado. Debe mostrar el nombre del hospital de un médico.

# %%
def get_doctors(hospital_id):
    #Fetch All doctors within given Hospital
    pass

get_doctors(2)

# %% [markdown]
# 18. Actualice la experiencia del médico en años
# El valor de la columna de experiencia para cada médico es nulo. Implementar la funcionalidad para actualizar la experiencia de un médico determinado en años.

# %%
def update_doctor_experience(doctor_id):
    # Update Doctor Experience in Years
    pass

update_doctor_experience(101)

# %% [markdown]
# **NOTA: El resultado debe verse como sigue**
#
# - Antes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Después

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Prueba técnica para el ROL de NoSQL Junior
#
# Los datos para la prueba están en el siguiente repositorio de Github:
# - https://github.com/AlanCIO/restaurants
#
#
# 1. Escriba una consulta de MongoDB para mostrar todos los documentos de la colección de restaurantes.

# %% [markdown]
# 2. Escriba una consulta de MongoDB para mostrar los campos restaurant_id, nombre, municipio y cocina para todos los documentos en el restaurante de la colección.

# %% [markdown]
# 3. Escriba una consulta de MongoDB para mostrar los campos restaurant_id, nombre, municipio y cocina, pero excluya el campo _id para todos los documentos de la colección restaurantes

# %% [markdown]
# 4. Escriba una consulta de MongoDB para mostrar los campos restaurant_id, nombre, municipio y código postal, pero excluya el campo _id para todos los documentos de la colección restaurant.

# %% [markdown]
# 5. Escriba una consulta de MongoDB para mostrar todos los restaurantes que se encuentran en el distrito del Bronx.

# %% [markdown]
# 6. Escriba una consulta de MongoDB para mostrar los primeros 5 restaurantes que se encuentran en el condado del Bronx

# %% [markdown]
# 7.Escriba una consulta de MongoDB para mostrar los siguientes 5 restaurantes después de omitir los primeros 5 que se encuentran en el condado del Bronx.

# %% [markdown]
# 8. Escriba una consulta de MongoDB para encontrar los restaurantes que obtuvieron una puntuación superior a 90.

# %% [markdown]
# 9. Escriba una consulta de MongoDB para encontrar los restaurantes que obtuvieron una puntuación, más de 80 pero menos de 100.

# %% [markdown]
# 10. Escriba una consulta de MongoDB para encontrar los restaurantes que se ubican en un valor de latitud menor que -95.754168.

# %% [markdown]
# 11. Escriba una consulta de MongoDB para encontrar los restaurantes que no preparan ningún tipo de cocina de 'estadounidense' y su puntuación de calificación es superior a 70 y latitud inferior a -65.754168.

# %% [markdown]
# 12. Escriba una consulta de MongoDB para encontrar los restaurantes que no preparan ninguna cocina de 'estadounidense' y lograron una puntuación superior a 70 y se ubicaron en la longitud inferior a -65.754168.
# Nota: Realice esta consulta sin usar el operador $and.

# %% [markdown]
# 13. Escriba una consulta de MongoDB para encontrar los restaurantes que no preparan ninguna cocina de 'estadounidense' y obtuvieron una calificación de 'A' que no pertenece al distrito de Brooklyn. El documento debe mostrarse según la cocina en orden descendente.

# %% [markdown]
# 14. Escriba una consulta de MongoDB para encontrar el ID del restaurante, el nombre, el municipio y la cocina de aquellos restaurantes que contienen 'Wil' como las primeras tres letras de su nombre.

# %% [markdown]
# 15. Escriba una consulta de MongoDB para encontrar el ID del restaurante, el nombre, el municipio y la cocina de aquellos restaurantes que contienen "ces" como las últimas tres letras de su nombre.

# %% [markdown]
# 16. Escriba una consulta de MongoDB para encontrar el ID del restaurante, el nombre, el municipio y la cocina de aquellos restaurantes que contienen 'Reg' como tres letras en algún lugar de su nombre.

# %% [markdown]
# 17. Escriba una consulta de MongoDB para encontrar los restaurantes que pertenecen al municipio del Bronx y que prepararon platos estadounidenses o chinos.

# %% [markdown]
# 18. Escriba una consulta de MongoDB para encontrar la identificación (ID) del restaurante, el nombre, el municipio y la cocina de los restaurantes que pertenecen al municipio de Staten Island, Queens o Bronxor Brooklyn.

# %% [markdown]
# #Soluciones
#
# Puedes consultar las soluciones a estos ejercicios en el siguiente colab:
#
# - [Soluciones Pruebas Técnicas SQL & NoSQL](https://colab.research.google.com/drive/1LAn49dpdMs0nmxUu2UUGx8l13s6S1pav?usp=sharing)
