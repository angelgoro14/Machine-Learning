# %% [markdown]
# ## **Código para el Problema del Banco**
# **Decidir cuándo otorgar préstamos**

# %% [markdown]
# Los pasos para resolver el problema con Ciencia de Datos son:
# 1.   **Entender el problema, y establecer la decisión a automatizar.** En este caso: Decidir otorgar o no otorgar un préstamo.
# 2.   **Recopilar datos confiables y relevantes.** Los datos se obtuvieron del repostorio público de Machine Learning de la universidad [UCI, Irvine](https://archive.ics.uci.edu/ml/datasets/Statlog+(German+Credit+Data)).
# 3.   **Procesar y Limpiar los datos.** Para este ejemplo, te ayudamos con este paso. Los datos limpios se almacenaron en un archivo cvs en un repositorio de Github.
# 4.   **Entrenamiento del modelo.** En este Colab entrenaremos 3 modelos distintos.
# 5.   **Evaluación del modelo.** En esta práctica evaluaremos los 3 modelos.
# 6.   **Producción.** Por lo pronto no llegaremos a este punto.
# 7.   **Monitoreo** Por lo pronto no llegaremos a este punto.
#
#
# ---
#
#
# 1. *Un **repositorio** es un espacio centralizado donde se almacena, organiza, mantiene y difunde información digital, habitualmente archivos informáticos, que pueden contener trabajos científicos, conjuntos de datos o software.*
# 2. *De Github recuperamos un archivo de valores separados por comas; en inglés comma-separated values, por eso la extensión **.csv** . Los [archivos CSV](https://es.wikipedia.org/wiki/Valores_separados_por_comas) son un tipo de documento en formato abierto sencillo para representar datos en forma de tabla.*
#
# ![](https://drive.google.com/uc?id=1zKz7y8l9yvJWGPPGUTNIIf86M1LNGB2z)

# %%
import pandas as pd  # Pandas ofrece estructuras de datos y operaciones para manipular tablas numéricas.
url = 'https://raw.githubusercontent.com/AlanCIO/Disruptora_DatasetLab0/master/CreditScoringClean.csv'
df = pd.read_csv(url) # Los datos se almacenan en un tipo de dato de pandas que se llama dataframe

# %% [markdown]
# Ahora los datos están en un dataframe con nombre **df**. Por lo general, un dataframe usado en aprendizaje de máquina se ve como sigue:
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;}
# .tg th{font-family:Arial, sans-serif;font-size:14px;font-weight:normal;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;}
# .tg .tg-c3ow{border-color:inherit;text-align:center;vertical-align:top}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
#   <tr>
#     <th class="tg-0pky"></th>
#     <th class="tg-0pky">Atributo 1</th>
#     <th class="tg-0pky">Atributo 2</th>
#     <th class="tg-0pky">...</th>
#     <th class="tg-0pky">Atributo <span style="font-style:italic">n</span></th>
#     <th class="tg-0pky">Clase</th>
#   </tr>
#   <tr>
#     <td class="tg-0pky">0</td>
#     <td class="tg-c3ow"></td>
#     <td class="tg-c3ow"></td>
#     <td class="tg-c3ow"></td>
#     <td class="tg-c3ow"></td>
#     <td class="tg-c3ow"></td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">1</td>
#     <td class="tg-c3ow"></td>
#     <td class="tg-c3ow"></td>
#     <td class="tg-c3ow"></td>
#     <td class="tg-c3ow"></td>
#     <td class="tg-c3ow"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">.<br>.<br>.</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0pky"><span style="font-style:italic">n</span></td>
#     <td class="tg-c3ow"></td>
#     <td class="tg-c3ow"></td>
#     <td class="tg-c3ow"></td>
#     <td class="tg-c3ow"></td>
#     <td class="tg-c3ow"></td>
#   </tr>
# </table>
#
# La primera columna indica el número del ejemplo para entrenar; en este caso sería un cliente. Después los datos o atributos de cada cliente se ubican en columnas siguientes. Un atributo para nuestro ejemplo sería el historial crediticio del cliente. La ultima columna contiene información sobre la clase, es decir si se le otrogó el préstamo al cliente con esos atributos, o no se le otorgó el préstamo.
#
#
# ---
#
# ¿Qué otros atributos tenemos en el dataset? 🤔 Puedes ver el contenido del dataframe ejecutando la siguiente celda. Las claves A11, A12, A30, entre otras hacen referencia al estatus del atributo.
#
# Por ejemplo, para el atributo *CreditHistory*, la clave A30 significa que el cliente no ha solicitado un prestamo con aterioridad. Puedes ver el significado de las claves restantes en la documentación del dataset [aquí](https://archive.ics.uci.edu/ml/datasets/Statlog+(German+Credit+Data)), bajo el apartado *Attribute Information*.

# %%
# Ver dataframe
df
# Out:
#      CheckingAcctStat A11  CheckingAcctStat A12  ...  Telephone1  CreditScore
# 0                       1                     0  ...           0            1
# 1                       0                     0  ...           1            0
# 2                       0                     0  ...           1            0
# 3                       1                     0  ...           1            1
# 4                       0                     0  ...           0            0
# ..                    ...                   ...  ...         ...          ...
# 945                     0                     1  ...           0            1
# 946                     1                     0  ...           0            1
# 947                     1                     0  ...           0            1
# 948                     1                     0  ...           0            1
# 949                     1                     0  ...           0            1
#
# [950 rows x 39 columns]

# %% [markdown]
# LLegamos al paso relacionado con el **entrenamiento del modelo** 💪. Para este paso, usaremos [scikit-learn](https://es.wikipedia.org/wiki/Scikit-learn) (también conocido como sklearn). Sklearn es de software libre, y contiene funciones para aprendizaje de máquina en Python.
#
# Los pasos para usar un modelo y entrenarlo son:
# 1. Importar el modelo de sklearn
# 2. Crear el modelo
# 3. Entrenar el modelo

# %%
# Usar y entrenar un modelo: Árbol de decisión
from sklearn.tree import DecisionTreeClassifier # Importar el modelo/algoritmo de sklearn
clf = DecisionTreeClassifier()                  # Crear el modelo

# %% [markdown]
# ¿Cuál es el siguiente paso? ... Exacto ✨, entrenar el modelo.

# %%
# Para entrenar el modelo, usaremos la función fit. Esta función toma dos parámetros.
# El primero es un arreglo con los atributos, y el segundo es un arreglo con las etiquetas de las clases.

# Como nuestros datos están en un dataframe que contiene tanto los atributos como las etiquetas, primero
# necesitamos separarlos en dos arreglos. Esto es fácil usando iloc en pandas.

# Los atributos son los valores de los ejemplos, y la etiqueta es el valor o clase que intentamos predecir
X = df.iloc[:,0:-1] # Atributos: Todas las filas, de todas las columnas exceptuando la última
y = df.iloc[:,-1]   # Etiqueta: Última columna, 'CreditScore' 0: Negar préstamo; 1: Asignar préstamo

# Ahora sí podemos entrenar el modelo con la función fit(X,y)
clf = clf.fit(X, y)

# %% [markdown]
# Listo, ya tienes un modelo entrenado. Asignemos una calificación a este modelo. En la práctica 4, hablaremos más sobre la evaluación de modelos de aprendizaje.

# %%
# Evaluar el modelo: Árbol de decisión
from sklearn.metrics import accuracy_score  
y_pred = clf.predict(X)                             # Usar los ejemplos de prueba para predecir

print('Calificación: ', accuracy_score(y, y_pred))  # Comparar las predicciones con los valores
                                                    # reales de las etiquetas de prueba
# Out:
# Calificación:  1.0

# %% [markdown]
# Ejecuta las siguientes celdas para entrenar y evaluar dos modelos más.

# %%
# Entrenar un modelo: Gaussian Näive Bayes
from sklearn.naive_bayes import GaussianNB  # Importar el modelo de sklearn
clf = GaussianNB()                          # Crear el modelo
clf = clf.fit(X, y)                         # Entrenar el modelo. Recuerda: En una celda anterior ya hemos
                                            # asignado a "X" los atributos, y a "y" las etiquetas de las clases

# Evaluar el modelo: Gaussian Näive Bayes
y_pred = clf.predict(X)                # usar los ejemplos de prueba para predecir

print('Calificación: ', accuracy_score(y, y_pred))  # Comparar las predicciones con los valores
                                                    # reales de las etiquetas de prueba
# Out:
# Calificación:  0.7347368421052631

# %%
950* 0.7347368421052631
# Out:
# 698.0

# %%
# Entrenar un modelo: Máquina de Vectores de Soporte SVM
# Equivalente a  from sklearn.svm import SVC
from sklearn import svm               # Importar el modelo de sklearn
clf = svm.SVC()                       # Crear el modelo
clf = clf.fit(X, y)                   # Entrenar el modelo

# Evaluar el modelo: Máquina de Vectores de Soporte SVM
y_pred = clf.predict(X)          # usar los ejemplos de prueba para predecir

print('Calificación: ', accuracy_score(y, y_pred))  # Comparar las predicciones con los valores
                                                    # reales de las etiquetas de prueba
# Out:
# Calificación:  0.8578947368421053

# %%
950*0.8578947368421053
# Out:
# 815.0
